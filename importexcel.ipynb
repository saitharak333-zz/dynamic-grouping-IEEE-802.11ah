# %%
import pandas as pd
db = pd.read_excel('/home/tharak/Desktop/Major/dataset.xlsx')
print(db)
# Out:
#       DataRate  Payload Size  No of Stations  No of Slots  Beacon Interval  \
# 0         0.65           256              30            5            40960
# 1         0.65           256              40            5            40960
# 2         0.65           256              50            5            40960
# 3         0.65           256              30            5            40960
# 4         0.65           256              40            5            40960
# 5         0.65           256              50            5            40960
# 6         0.65           256              60            5            40960
# 7         0.65           256              70            5            40960
# 8         0.65           256              30            5            40960
# 9         0.65           256              40            5            40960
# 10        0.65           256              50            5            40960
# ...

# %%
db1 = db[["No of Slots"]]
print(db1)
db2 = db[["No of Stations"]]
print(db2)
db3 = db[["Beacon Interval"]]
print(db3)
db4 = db[["Throughput"]]
print(db4)
# Out:
#       No of Slots
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
# 5               5
# 6               5
# 7               5
# 8               5
# 9               5
# 10              5
# 11              5
# 12              5
# 13              5
# 14              5
# 15              5
# 16              5
# 17              5
# 18              5
# 19              5
# 20              5
# 21              5
# 22              5
# 23              5
# 24              5
# 25              5
# 26              5
# 27              5
# 28              5
# 29              5
# ...           ...
# 9428            1
# 9429            1
# 9430            1
# 9431            1
# 9432            1
# 9433            1
# 9434            1
# 9435            1
# 9436            1
# 9437            1
# 9438            1
# 9439            1
# 9440            1
# 9441            1
# 9442            1
# 9443            1
# 9444            1
# 9445            1
# ...

# %% [raw]
# print(db1[1])
