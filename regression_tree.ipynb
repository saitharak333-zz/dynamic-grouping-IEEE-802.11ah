# %%
import pandas as pd
df = pd.read_excel('dataset.xlsx')
df
# Out:
#       No of Stations  No of Slots  Beacon Interval  Throughput
# 0                 30            5            40960    0.177191
# 1                 40            5            40960    0.179372
# 2                 50            5            40960    0.180525
# 3                 30            5            40960    0.166819
# 4                 40            5            40960    0.163567
# 5                 50            5            40960    0.170325
# 6                 60            5            40960    0.166633
# 7                 70            5            40960    0.170721
# 8                 30            5            40960    0.230400
# 9                 40            5            40960    0.223046
# 10                50            5            40960    0.218405
# 11                60            5            40960    0.215642
# 12                30            5            40960    0.230400
# 13                40            5            40960    0.223046
# 14                50            5            40960    0.218405
# 15                60            5            40960    0.215642
# 16                70            5            40960    0.213402
# 17                80            5            40960    0.212369
# 18                90            5            40960    0.210393
# 19               100            5            40960    0.209178
# 20               110            5            40960    0.206464
# 21               120            5            40960    0.212329
# 22               130            5            40960    0.209616
# 23               140            5            40960    0.206131
# 24               150            5            40960    0.211383
# 25               160            5            40960    0.204132
# 26               170            5            40960    0.207981
# 27               180            5            40960    0.208568
# 28               190            5            40960    0.208935
# 29               200            5            40960    0.212915
# ...              ...          ...              ...         ...
# 9428             110            1           204800    0.318259
# 9429             120            1           204800    0.328070
# 9430             130            1           204800    0.319132
# 9431             140            1           204800    0.317686
# 9432             150            1           204800    0.326420
# 9433             160            1           204800    0.308189
# 9434             170            1           204800    0.314095
# 9435             180            1           204800    0.312128
# 9436             190            1           204800    0.304309
# 9437             200            1           204800    0.301796
# 9438             210            1           204800    0.297176
# 9439             220            1           204800    0.304627
# 9440             230            1           204800    0.298808
# 9441             240            1           204800    0.296150
# 9442             250            1           204800    0.293046
# 9443             260            1           204800    0.285805
# 9444             270            1           204800    0.293547
# 9445             280            1           204800    0.290406
# 9446             290            1           204800    0.291539
# 9447             300            1           204800    0.288807
# 9448             310            1           204800    0.279991
# 9449             320            1           204800    0.273585
# 9450             330            1           204800    0.278459
# 9451             340            1           204800    0.282078
# 9452             350            1           204800    0.263328
# 9453             360            1           204800    0.266713
# 9454             370            1           204800    0.280450
# 9455             380            1           204800    0.281507
# 9456             390            1           204800    0.266679
# 9457             400            1           204800    0.271682
#
# [9458 rows x 4 columns]

# %%
df_norm = (df - df.mean())/(df.max() - df.min())
df_norm
# Out:
#       No of Stations  No of Slots  Beacon Interval  Throughput
# 0          -0.308010    -0.412621        -0.448291   -0.376428
# 1          -0.295023    -0.412621        -0.448291   -0.368167
# 2          -0.282036    -0.412621        -0.448291   -0.363800
# 3          -0.308010    -0.412621        -0.448291   -0.415711
# 4          -0.295023    -0.412621        -0.448291   -0.428027
# 9450        0.081601    -0.494254         0.551709    0.007115
# 9451        0.094588    -0.494254         0.551709    0.020822
# 9452        0.107575    -0.494254         0.551709   -0.050192
# 9453        0.120562    -0.494254         0.551709   -0.037372
# 9454        0.133549    -0.494254         0.551709    0.014656
# 9455        0.146536    -0.494254         0.551709    0.018659
# 9456        0.159523    -0.494254         0.551709   -0.037500
# 9457        0.172510    -0.494254         0.551709   -0.018552
#
# [9458 rows x 4 columns]

# %% [markdown]
# from sklearn.model_selection import train_test_split
# x = df[['No of Stations', 'No of Slots', 'Beacon Interval']]
# y = df[['Throughput']]
# x_norm = df_norm[['No of Stations', 'No of Slots', 'Beacon Interval']]
# y_norm = df_norm[['Throughput']]
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
# x_norm_train, x_norm_test, y_norm_train, y_norm_test = train_test_split(x_norm, y_norm, test_size = 0.2, random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1_norm = DecisionTreeRegressor(max_depth=2)
regr_2_norm = DecisionTreeRegressor(max_depth=5)
regr_1.fit(x_train, y_train)
regr_2.fit(x_train, y_train)
regr_1_norm.fit(x_norm_train, y_norm_train)
regr_2_norm.fit(x_norm_train, y_norm_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0fadb5a26e28> in <module>
#       4 regr_1_norm = DecisionTreeRegressor(max_depth=2)
#       5 regr_2_norm = DecisionTreeRegressor(max_depth=5)
# ----> 6 regr_1.fit(x_train, y_train)
#       7 regr_2.fit(x_train, y_train)
#       8 regr_1_norm.fit(x_norm_train, y_norm_train)
#
# NameError: name 'x_train' is not defined

# %%
y_1 = regr_1.predict(x_test)
y_2 = regr_2.predict(x_test)
y_1_norm = regr_1_norm.predict(x_norm_test)
y_2_norm = regr_2_norm.predict(x_norm_test)

# %%
y_1
# Out:
# array([0.28576485, 0.28576485, 0.23140102, ..., 0.27832001, 0.25242343,
#        0.27832001])

# %%
from sklearn.metrics import accuracy_score
print("Accuracy score without norm and max_depth as 2: " + str(accuracy_score(y_test, y_1))
print("Accuracy score without norm and max_depth as 5: " + str(accuracy_score(y_test, y_2))
print("Accuracy score with norm and max_depth as 2: " + str(accuracy_score(y_norm_test, y_1_norm))
print("Accuracy score with norm and max_depth as 5: " + str(accuracy_score(y_norm_test, y_2_norm))
# Out:
# Accuracy score without norm and max_depth as 2:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ab227a4f9e7> in <module>
#       1 from sklearn.metrics import accuracy_score
#       2 print("Accuracy score without norm and max_depth as 2:", end = ' ')
# ----> 3 print(accuracy_score(y_test, y_1))
#       4 print("Accuracy score without norm and max_depth as 5:", end = ' ')
#       5 print(accuracy_score(y_test, y_2))
#
# NameError: name 'y_test' is not defined
