# %%
import pandas as pd
df = pd.read_excel('dataset.xlsx')
df
# Out:
#       No of Stations  No of Slots  Beacon Interval  Throughput
# 0                 30            5            71680    0.263314
# 1                 40            5            71680    0.272156
# 2                 50            5            71680    0.277969
# 3                 60            5            71680    0.281836
# 4                 70            5            71680    0.285082
# 5                 80            5            71680    0.285997
# 6                 90            5            71680    0.288121
# 7                100            5            71680    0.288183
# 8                110            5            71680    0.276395
# 9                120            5            71680    0.287949
# 10               130            5            71680    0.276626
# 11               140            5            71680    0.267231
# 12               150            5            71680    0.277824
# 13               160            5            71680    0.274312
# ...

# %%
df_norm = (df - df.mean())/(df.max() - df.min())
df_norm
# Out:
#       No of Stations  No of Slots  Beacon Interval  Throughput
# 0          -0.500000    -0.421283        -0.302198   -0.058063
# 1          -0.478723    -0.421283        -0.302198   -0.024575
# 2          -0.457447    -0.421283        -0.302198   -0.002559
# 3          -0.436170    -0.421283        -0.302198    0.012087
# 4          -0.414894    -0.421283        -0.302198    0.024381
# 5          -0.393617    -0.421283        -0.302198    0.027846
# 6          -0.372340    -0.421283        -0.302198    0.035891
# 7          -0.351064    -0.421283        -0.302198    0.036126
# 8          -0.329787    -0.421283        -0.302198   -0.008520
# 9          -0.308511    -0.421283        -0.302198    0.035239
# 10         -0.287234    -0.421283        -0.302198   -0.007645
# 11         -0.265957    -0.421283        -0.302198   -0.043228
# 12         -0.244681    -0.421283        -0.302198   -0.003108
# 13         -0.223404    -0.421283        -0.302198   -0.016409
# ...

# %%
from sklearn.model_selection import train_test_split
x = df[['No of Stations', 'Beacon Interval','Throughput']] 
y = df[['No of Slots']] 
x_norm = df_norm[['No of Stations', 'Beacon Interval','Throughput']]
y_norm = df_norm[['No of Slots']] 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42) 
x_norm_train, x_norm_test, y_norm_train, y_norm_test = train_test_split(x_norm, y_norm, test_size = 0.2, random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1_norm = DecisionTreeRegressor(max_depth=2)
regr_2_norm = DecisionTreeRegressor(max_depth=5)
regr_1.fit(x_train, y_train)
regr_2.fit(x_train, y_train)
regr_1_norm.fit(x_norm_train, y_norm_train)
regr_2_norm.fit(x_norm_train, y_norm_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_1 = regr_1.predict(x_test)
y_2 = regr_2.predict(x_test)
y_1_norm = regr_1_norm.predict(x_norm_test)
y_2_norm = regr_2_norm.predict(x_norm_test)

# %%
y_1
# Out:
# array([17.00910125, 30.63694471, 30.55659398, ..., 17.00910125,
#        30.63694471, 30.63694471])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_1)
# Out:
# 0.13119782276708125

# %%
r2_score(y_test, y_2)
# Out:
# 0.29645862693815195

# %%
r2_score(y_norm_test, y_1_norm)
# Out:
# 0.13119782276708125

# %%
r2_score(y_norm_test, y_2_norm)
# Out:
# 0.29645862693815206

# %%
regr_3_norm = DecisionTreeRegressor(max_depth=10)
regr_3_norm.fit(x_norm_train, y_norm_train)
y_3_norm = regr_3_norm.predict(x_norm_test)

# %%
r2_score(y_norm_test, y_3_norm)
# Out:
# 0.24211162118022667

# %%
regr_4_norm = DecisionTreeRegressor(max_depth=20)
regr_4_norm.fit(x_norm_train, y_norm_train)
y_4_norm = regr_4_norm.predict(x_norm_test)

# %%
r2_score(y_norm_test, y_4_norm)
# Out:
# -0.0847324753641403

# %%
regr_5_norm = DecisionTreeRegressor(max_depth=3)
regr_5_norm.fit(x_norm_train, y_norm_train)
y_5_norm = regr_5_norm.predict(x_norm_test)
r2_score(y_norm_test, y_5_norm)
# Out:
# 0.23794843155040057

# %%
regr_6_norm = DecisionTreeRegressor(max_depth=4)
regr_6_norm.fit(x_norm_train, y_norm_train)
y_6_norm = regr_6_norm.predict(x_norm_test)
r2_score(y_norm_test, y_6_norm)
# Out:
# 0.27941440341334534

# %%
regr_7_norm = DecisionTreeRegressor(max_depth=6)
regr_7_norm.fit(x_norm_train, y_norm_train)
y_7_norm = regr_7_norm.predict(x_norm_test)
r2_score(y_norm_test, y_7_norm)
# Out:
# 0.3152452539797782

# %%
regr_8_norm = DecisionTreeRegressor(max_depth=7)
regr_8_norm.fit(x_norm_train, y_norm_train)
y_8_norm = regr_8_norm.predict(x_norm_test)
r2_score(y_norm_test, y_8_norm)
# Out:
# 0.3178039077576339

# %%
regr_9_norm = DecisionTreeRegressor(max_depth=9)
regr_9_norm.fit(x_norm_train, y_norm_train)
y_9_norm = regr_9_norm.predict(x_norm_test)
r2_score(y_norm_test, y_9_norm)
# Out:
# 0.25805334130191804
